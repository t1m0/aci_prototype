# %%
from Application.PaparaziGame import PaparaziGame
from Application.plot_map import plot_map
import pandas as pd

# %%
game = PaparaziGame()

# %%
game_map = game.play("Maps/",num_security_guards=10, iterations=1)
# Out:
# Testmap_weighted_50
# Testmap_weighted_100
# Testmap_weighted_25
# Testmap_weighted_200
# Started Testmap_weighted_50 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_50 with None heuristic in 106 iterations and 0.69min
# Saving Visualization/Testmap_weighted_50_None_0.gif
# Started Testmap_weighted_100 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_100 with None heuristic in 258 iterations and 9.07min
# Saving Visualization/Testmap_weighted_100_None_0.gif
# Started Testmap_weighted_25 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_25 with None heuristic in 128 iterations and 0.42min
# Saving Visualization/Testmap_weighted_25_None_0.gif
# Started Testmap_weighted_200 with None heuristic
# Iteration 0 of 1
# Running longer than 15min currently at iteration 335 and 63.66min
# Finished Testmap_weighted_200 with None heuristic in 335 iterations and 63.66min
# Saving Visualization/Testmap_weighted_200_None_0.gif

# %%
columns=['name', 'time_elapsed', 'total_iteration', 'total_cost', 'path_length', 'heuristic', 'map','path']
df = pd.DataFrame([[getattr(i,j) for j in columns] for i in game_map], columns=columns)

# %%
df
# Out:
#                           name  time_elapsed  total_iteration  total_cost  \
# 0   Testmap_weighted_50_None_0          0.69              106         788
# 1  Testmap_weighted_100_None_0          9.07              258        2141
# 2   Testmap_weighted_25_None_0          0.42              128         858
# 3  Testmap_weighted_200_None_0         63.66              335        5340
#
#    path_length heuristic                                          map  \
# 0          107      None  <Application.Map.Map object at 0x11217bbb0>
# 1          259      None  <Application.Map.Map object at 0x11218d0d0>
# 2          129      None  <Application.Map.Map object at 0x1264e19d0>
# 3          336      None  <Application.Map.Map object at 0x12669c3d0>
#
#                                                 path
# 0  [<Application.Cell.Cell object at 0x126467e20>...
# 1  [<Application.Cell.Cell object at 0x1264f0b50>...
# 2  [<Application.Cell.Cell object at 0x1266a32b0>...
# 3  [<Application.Cell.Cell object at 0x1266c9e80>...

# %%
df.groupby('heuristic')[['total_cost', 'time_elapsed']].min()
# Out:
#            total_cost  time_elapsed
# heuristic
# None              788          0.42
