# %%
from Application.PaparaziGame import PaparaziGame
from Application.plot_map import plot_map
import pandas as pd

# %%
game = PaparaziGame()

# %%
game_map = game.play("Maps/",5)
# Out:
# Testmap_weighted_50
# Testmap_weighted_100
# Testmap_weighted_25
# Testmap_weighted_200
# Started Testmap_weighted_50 with None heuristic
# Finished Testmap_weighted_50 with None heuristic in 106 iterations and 13077.12ms
# Started Testmap_weighted_50 with Manhattan heuristic
# Finished Testmap_weighted_50 with Manhattan heuristic in 106 iterations and 11365.21ms
# Started Testmap_weighted_50 with Euclidean heuristic
# Finished Testmap_weighted_50 with Euclidean heuristic in 106 iterations and 11783.2ms
# Started Testmap_weighted_50 with Chebyshev heuristic
# Finished Testmap_weighted_50 with Chebyshev heuristic in 106 iterations and 12456.11ms
# Started Testmap_weighted_100 with None heuristic
# Finished Testmap_weighted_100 with None heuristic in 258 iterations and 396214.0ms
# Started Testmap_weighted_100 with Manhattan heuristic
# Finished Testmap_weighted_100 with Manhattan heuristic in 258 iterations and 381213.7ms
# Started Testmap_weighted_100 with Euclidean heuristic
# Finished Testmap_weighted_100 with Euclidean heuristic in 258 iterations and 386323.74ms
# Started Testmap_weighted_100 with Chebyshev heuristic
# Finished Testmap_weighted_100 with Chebyshev heuristic in 258 iterations and 390378.98ms
# Started Testmap_weighted_25 with None heuristic
# Finished Testmap_weighted_25 with None heuristic in 130 iterations and 1945.63ms
# Started Testmap_weighted_25 with Manhattan heuristic
# Finished Testmap_weighted_25 with Manhattan heuristic in 114 iterations and 1813.7ms
# Started Testmap_weighted_25 with Euclidean heuristic
# Finished Testmap_weighted_25 with Euclidean heuristic in 118 iterations and 2859.44ms
# Started Testmap_weighted_25 with Chebyshev heuristic
# Finished Testmap_weighted_25 with Chebyshev heuristic in 128 iterations and 1877.27ms
# Started Testmap_weighted_200 with None heuristic
# Running longer than 15min currently at iteration 57
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with None heuristic in 335 iterations and 3289687.31ms
# Weight 191 not found!
# Weight 282 not found!
# Started Testmap_weighted_200 with Manhattan heuristic
# Running longer than 15min currently at iteration 60
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with Manhattan heuristic in 335 iterations and 3157632.81ms
# Weight 191 not found!
# Weight 282 not found!
# Started Testmap_weighted_200 with Euclidean heuristic
# Running longer than 15min currently at iteration 59
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with Euclidean heuristic in 335 iterations and 3218219.49ms
# Weight 191 not found!
# Weight 282 not found!
# Started Testmap_weighted_200 with Chebyshev heuristic
# Running longer than 15min currently at iteration 57
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with Chebyshev heuristic in 335 iterations and 3273388.55ms
# Weight 191 not found!
# Weight 282 not found!

# %%
columns=['uuid', 'time_elapsed', 'total_iteration', 'total_cost', 'path_length', 'heuristic', 'map','path']
df = pd.DataFrame([[getattr(i,j) for j in columns] for i in game_map], columns=columns)

# %%
df
# Out:
#                                     uuid  time_elapsed  total_iteration  \
# 0   4092ea86-dd31-11ec-83b1-acde48001122      0.217952              106
# 1   4787c1ea-dd31-11ec-83b1-acde48001122      0.189420              106
# 2   4eb3ec3c-dd31-11ec-83b1-acde48001122      0.196387              106
# 3   5649c6b0-dd31-11ec-83b1-acde48001122      0.207602              106
# 4   42bae2d6-dd32-11ec-83b1-acde48001122      6.603567              258
# 5   264226ea-dd33-11ec-83b1-acde48001122      6.353562              258
# 6   0ccce9b0-dd34-11ec-83b1-acde48001122      6.438729              258
# 7   f5c21b54-dd34-11ec-83b1-acde48001122      6.506316              258
# 8   f70b94a4-dd34-11ec-83b1-acde48001122      0.032427              130
# 9   f8365530-dd34-11ec-83b1-acde48001122      0.030228              114
# 10  fa0097a4-dd34-11ec-83b1-acde48001122      0.047657              118
# 11  fb357428-dd34-11ec-83b1-acde48001122      0.031288              128
# 12  a48accc4-dd3c-11ec-83b1-acde48001122     54.828122              335
# 13  ff3641ce-dd43-11ec-83b1-acde48001122     52.627214              335
# 14  7e069e8e-dd4b-11ec-83b1-acde48001122     53.636991              335
# 15  1db14de2-dd53-11ec-83b1-acde48001122     54.556476              335
#
#     total_cost  path_length  heuristic  \
# 0          788          107       None
# 1          792          107  Manhattan
# 2          792          107  Euclidean
# 3          788          107  Chebyshev
# 4         2141          259       None
# 5         2141          259  Manhattan
# 6         2141          259  Euclidean
# 7         2141          259  Chebyshev
# 8          938          131       None
# 9          904          115  Manhattan
# 10        3841          119  Euclidean
# 11         876          129  Chebyshev
# 12        5340          336       None
# 13        5342          336  Manhattan
# 14        5340          336  Euclidean
# 15        5340          336  Chebyshev
#
#                                             map  \
# 0   <Application.Map.Map object at 0x105b2b310>
# 1   <Application.Map.Map object at 0x105b2b310>
# 2   <Application.Map.Map object at 0x105b2b310>
# 3   <Application.Map.Map object at 0x105b2b310>
# 4   <Application.Map.Map object at 0x105eda6a0>
# 5   <Application.Map.Map object at 0x105eda6a0>
# 6   <Application.Map.Map object at 0x105eda6a0>
# 7   <Application.Map.Map object at 0x105eda6a0>
# 8   <Application.Map.Map object at 0x11a15e040>
# 9   <Application.Map.Map object at 0x11a15e040>
# 10  <Application.Map.Map object at 0x11a15e040>
# 11  <Application.Map.Map object at 0x11a15e040>
# 12  <Application.Map.Map object at 0x11a316820>
# 13  <Application.Map.Map object at 0x11a316820>
# 14  <Application.Map.Map object at 0x11a316820>
# 15  <Application.Map.Map object at 0x11a316820>
#
#                                                  path
# 0   [<Application.Cell.Cell object at 0x11a0e2640>...
# 1   [<Application.Cell.Cell object at 0x11a0e2640>...
# 2   [<Application.Cell.Cell object at 0x11a0e2640>...
# 3   [<Application.Cell.Cell object at 0x11a0e2640>...
# 4   [<Application.Cell.Cell object at 0x11a16a1c0>...
# 5   [<Application.Cell.Cell object at 0x11a16a1c0>...
# 6   [<Application.Cell.Cell object at 0x11a16a1c0>...
# 7   [<Application.Cell.Cell object at 0x11a16a1c0>...
# 8   [<Application.Cell.Cell object at 0x11a31c700>...
# 9   [<Application.Cell.Cell object at 0x11a31c700>...
# 10  [<Application.Cell.Cell object at 0x11a31c700>...
# 11  [<Application.Cell.Cell object at 0x11a31c700>...
# 12  [<Application.Cell.Cell object at 0x11a34a130>...
# 13  [<Application.Cell.Cell object at 0x11a34a130>...
# 14  [<Application.Cell.Cell object at 0x11a34a130>...
# 15  [<Application.Cell.Cell object at 0x11a34a130>...

# %%
df.groupby('heuristic')[['total_cost', 'time_elapsed']].min()
# Out:
#            total_cost  time_elapsed
# heuristic
# Chebyshev         788      0.031288
# Euclidean         792      0.047657
# Manhattan         792      0.030228
# None              788      0.032427
