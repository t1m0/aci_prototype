# %%
from Application.PaparaziGame import PaparaziGame
from Application.plot_map import plot_map
import pandas as pd

# %%
game = PaparaziGame()

# %%
game_map = game.play("Maps/",num_security_guards=10, iterations=1)
# Out:
# Testmap_weighted_50
# Testmap_weighted_100
# Testmap_weighted_25
# Testmap_weighted_200
# Started Testmap_weighted_50 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_50 with None heuristic in 108 iterations and 0.7min
# Saving Visualization/Testmap_weighted_50_None_0.gif
# Started Testmap_weighted_100 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_100 with None heuristic in 258 iterations and 9.15min
# Saving Visualization/Testmap_weighted_100_None_0.gif
# Started Testmap_weighted_25 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_25 with None heuristic in 128 iterations and 0.44min
# Saving Visualization/Testmap_weighted_25_None_0.gif
# Started Testmap_weighted_200 with None heuristic
# Iteration 0 of 1
# Running longer than 15min currently at iteration 335 and 77.34min
# Finished Testmap_weighted_200 with None heuristic in 335 iterations and 77.34min
# Saving Visualization/Testmap_weighted_200_None_0.gif

# %%
columns=['name', 'time_elapsed', 'total_iteration', 'total_cost', 'path_length', 'heuristic', 'map','path']
df = pd.DataFrame([[getattr(i,j) for j in columns] for i in game_map], columns=columns)

# %%
df
# Out:
#                           name  time_elapsed  total_iteration  total_cost  \
# 0   Testmap_weighted_50_None_0          0.70              108         790
# 1  Testmap_weighted_100_None_0          9.15              258        2141
# 2   Testmap_weighted_25_None_0          0.44              128         848
# 3  Testmap_weighted_200_None_0         77.34              335        5340
#
#    path_length heuristic                                          map  \
# 0          109      None  <Application.Map.Map object at 0x1081f3d60>
# 1          259      None  <Application.Map.Map object at 0x104076940>
# 2          129      None  <Application.Map.Map object at 0x118297a60>
# 3          336      None  <Application.Map.Map object at 0x118455460>
#
#                                                 path
# 0  [<Application.Cell.Cell object at 0x11821ceb0>...
# 1  [<Application.Cell.Cell object at 0x1182a9be0>...
# 2  [<Application.Cell.Cell object at 0x118459340>...
# 3  [<Application.Cell.Cell object at 0x118480f10>...

# %%
df.groupby('heuristic')[['total_cost', 'time_elapsed']].min()
# Out:
#            total_cost  time_elapsed
# heuristic
# None              790          0.44
