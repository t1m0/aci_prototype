# %%
from Application.PaparaziGame import PaparaziGame
from Application.plot_map import plot_map
import pandas as pd

# %%
game = PaparaziGame()

# %%
game_map = game.play("Maps/",num_security_guards=10, iterations=1)
# Out:
# Testmap_weighted_50
# Testmap_weighted_100
# Testmap_weighted_25
# Testmap_weighted_200
# Skipping map of size 200!
# Started Testmap_weighted_50 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_50 with None heuristic in 73 iterations and 0.57min
# Saving Visualization/Testmap_weighted_50_None_0.gif
# Started Testmap_weighted_100 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_100 with None heuristic in 23 iterations and 0.22min
# Saving Visualization/Testmap_weighted_100_None_0.gif
# Started Testmap_weighted_25 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_25 with None heuristic in 58 iterations and 0.21min
# Saving Visualization/Testmap_weighted_25_None_0.gif

# %%
columns=['name', 'time_elapsed', 'total_iteration', 'total_cost', 'path_length', 'heuristic', 'map','path']
df = pd.DataFrame([[getattr(i,j) for j in columns] for i in game_map], columns=columns)

# %%
df
# Out:
#                           name  time_elapsed  total_iteration  total_cost  \
# 0   Testmap_weighted_50_None_0          0.57               73         595
# 1  Testmap_weighted_100_None_0          0.22               23        3100
# 2   Testmap_weighted_25_None_0          0.21               58       18631
#
#    path_length heuristic                                          map  \
# 0           74      None  <Application.Map.Map object at 0x105a99ee0>
# 1           24      None  <Application.Map.Map object at 0x105ac9520>
# 2           59      None  <Application.Map.Map object at 0x119de4be0>
#
#                                                 path
# 0  [<Application.Cell.Cell object at 0x119d6c070>...
# 1  [<Application.Cell.Cell object at 0x119df5d60>...
# 2  [<Application.Cell.Cell object at 0x119fa74c0>...

# %%
df.groupby('heuristic')[['total_cost', 'time_elapsed']].min()
# Out:
#            total_cost  time_elapsed
# heuristic
# None              595          0.21
