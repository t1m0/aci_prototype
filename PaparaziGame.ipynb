# %%
from Application.PaparaziGame import PaparaziGame
from Application.plot_map import plot_map
import pandas as pd

# %%
game = PaparaziGame()

# %%
game_map = game.play("Maps/",num_security_guards=10, iterations=1)
# Out:
# Testmap_weighted_50
# Testmap_weighted_100
# Testmap_weighted_25
# Testmap_weighted_200
# Skipping map of size 200!
# Started Testmap_weighted_50 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_50 with None heuristic in 93 iterations and 0.88min
# Saving Visualization/Testmap_weighted_50_None_0.gif
# Started Testmap_weighted_100 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_100 with None heuristic in 257 iterations and 12.29min
# Saving Visualization/Testmap_weighted_100_None_0.gif
# Started Testmap_weighted_25 with None heuristic
# Iteration 0 of 1
# Finished Testmap_weighted_25 with None heuristic in 33 iterations and 0.2min
# Saving Visualization/Testmap_weighted_25_None_0.gif

# %%
columns=['name', 'time_elapsed', 'total_iteration', 'total_cost', 'path_length', 'heuristic', 'map','path']
df = pd.DataFrame([[getattr(i,j) for j in columns] for i in game_map], columns=columns)

# %%
df
# Out:
#                           name  time_elapsed  total_iteration  total_cost  \
# 0   Testmap_weighted_50_None_0          0.88               93        3809
# 1  Testmap_weighted_100_None_0         12.29              257        1879
# 2   Testmap_weighted_25_None_0          0.20               33       18165
#
#    path_length heuristic                   map  \
# 0           94      None   Testmap_weighted_50
# 1          258      None  Testmap_weighted_100
# 2           34      None   Testmap_weighted_25
#
#                                                 path
# 0  [<Application.Cell.Cell object at 0x122146070>...
# 1  [<Application.Cell.Cell object at 0x1221d0d60>...
# 2  [<Application.Cell.Cell object at 0x1223824c0>...

# %%
df.groupby('heuristic')[['map','total_cost', 'time_elapsed']].min()
# Out:
#                             map  total_cost  time_elapsed
# heuristic
# None       Testmap_weighted_100        1879           0.2
