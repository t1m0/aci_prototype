# %%
from Application.PaparaziGame import PaparaziGame
from Application.plot_map import plot_map
import pandas as pd

# %%
game = PaparaziGame()

# %%
game_map = game.play("Maps/",5)
# Out:
# Testmap_weighted_50
# Testmap_weighted_100
# Testmap_weighted_25
# Testmap_weighted_200
# Started Testmap_weighted_50 with None heuristic
# Finished Testmap_weighted_50 with None heuristic in 106 iterations and 0.22min
# Started Testmap_weighted_50 with Manhattan heuristic
# Finished Testmap_weighted_50 with Manhattan heuristic in 106 iterations and 0.19min
# Started Testmap_weighted_50 with Euclidean heuristic
# Finished Testmap_weighted_50 with Euclidean heuristic in 110 iterations and 0.2min
# Started Testmap_weighted_50 with Chebyshev heuristic
# Finished Testmap_weighted_50 with Chebyshev heuristic in 106 iterations and 0.2min
# Started Testmap_weighted_100 with None heuristic
# Finished Testmap_weighted_100 with None heuristic in 258 iterations and 6.91min
# Started Testmap_weighted_100 with Manhattan heuristic
# Finished Testmap_weighted_100 with Manhattan heuristic in 258 iterations and 6.41min
# Started Testmap_weighted_100 with Euclidean heuristic
# Finished Testmap_weighted_100 with Euclidean heuristic in 258 iterations and 6.41min
# Started Testmap_weighted_100 with Chebyshev heuristic
# Finished Testmap_weighted_100 with Chebyshev heuristic in 258 iterations and 6.47min
# Started Testmap_weighted_25 with None heuristic
# Finished Testmap_weighted_25 with None heuristic in 118 iterations and 0.05min
# Started Testmap_weighted_25 with Manhattan heuristic
# Finished Testmap_weighted_25 with Manhattan heuristic in 116 iterations and 0.03min
# Started Testmap_weighted_25 with Euclidean heuristic
# Finished Testmap_weighted_25 with Euclidean heuristic in 128 iterations and 0.03min
# Started Testmap_weighted_25 with Chebyshev heuristic
# Finished Testmap_weighted_25 with Chebyshev heuristic in 126 iterations and 0.03min
# Started Testmap_weighted_200 with None heuristic
# Running longer than 15min currently at iteration 335 and 55.15min
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with None heuristic in 335 iterations and 55.15min
# Weight 191 not found!
# Weight 282 not found!
# Started Testmap_weighted_200 with Manhattan heuristic
# Running longer than 15min currently at iteration 335 and 53.56min
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with Manhattan heuristic in 335 iterations and 53.56min
# Weight 191 not found!
# Weight 282 not found!
# Started Testmap_weighted_200 with Euclidean heuristic
# Running longer than 15min currently at iteration 335 and 54.1min
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with Euclidean heuristic in 335 iterations and 54.1min
# Weight 191 not found!
# Weight 282 not found!
# Started Testmap_weighted_200 with Chebyshev heuristic
# Running longer than 15min currently at iteration 335 and 55.2min
# Weight 191 not found!
# Weight 282 not found!
# Finished Testmap_weighted_200 with Chebyshev heuristic in 335 iterations and 55.2min
# Weight 191 not found!
# Weight 282 not found!

# %%
columns=['uuid', 'time_elapsed', 'total_iteration', 'total_cost', 'path_length', 'heuristic', 'map','path']
df = pd.DataFrame([[getattr(i,j) for j in columns] for i in game_map], columns=columns)

# %%
df
# Out:
#                                     uuid  time_elapsed  total_iteration  \
# 0   1a661a40-df57-11ec-a69b-acde48001122          0.22              106
# 1   214aaea2-df57-11ec-a69b-acde48001122          0.19              106
# 2   28b7b266-df57-11ec-a69b-acde48001122          0.20              110
# 3   2fe854be-df57-11ec-a69b-acde48001122          0.20              106
# 4   275a373a-df58-11ec-a69b-acde48001122          6.91              258
# 5   0cc84294-df59-11ec-a69b-acde48001122          6.41              258
# 6   f22510d8-df59-11ec-a69b-acde48001122          6.41              258
# 7   d9bb6dd4-df5a-11ec-a69b-acde48001122          6.47              258
# 8   db9652d6-df5a-11ec-a69b-acde48001122          0.05              118
# 9   dcc976ec-df5a-11ec-a69b-acde48001122          0.03              116
# 10  de0274fa-df5a-11ec-a69b-acde48001122          0.03              128
# 11  df3df7fe-df5a-11ec-a69b-acde48001122          0.03              126
# 12  94b1f282-df62-11ec-a69b-acde48001122         55.15              335
# 13  11613ac0-df6a-11ec-a69b-acde48001122         53.56              335
# 14  a148566c-df71-11ec-a69b-acde48001122         54.10              335
# 15  58a847e8-df79-11ec-a69b-acde48001122         55.20              335
#
#     total_cost  path_length  heuristic  \
# 0          788          107       None
# 1          792          107  Manhattan
# 2          812          111  Euclidean
# 3          788          107  Chebyshev
# 4         2141          259       None
# 5         2141          259  Manhattan
# 6         2141          259  Euclidean
# 7         2141          259  Chebyshev
# 8         3825          119       None
# 9          864          117  Manhattan
# 10         848          129  Euclidean
# 11         852          127  Chebyshev
# 12        5340          336       None
# 13        5342          336  Manhattan
# 14        5340          336  Euclidean
# 15        5340          336  Chebyshev
#
#                                             map  \
# 0   <Application.Map.Map object at 0x113bf2eb0>
# 1   <Application.Map.Map object at 0x113bf2eb0>
# 2   <Application.Map.Map object at 0x113bf2eb0>
# 3   <Application.Map.Map object at 0x113bf2eb0>
# 4   <Application.Map.Map object at 0x10e1d9d90>
# 5   <Application.Map.Map object at 0x10e1d9d90>
# 6   <Application.Map.Map object at 0x10e1d9d90>
# 7   <Application.Map.Map object at 0x10e1d9d90>
# 8   <Application.Map.Map object at 0x12249f1f0>
# 9   <Application.Map.Map object at 0x12249f1f0>
# 10  <Application.Map.Map object at 0x12249f1f0>
# 11  <Application.Map.Map object at 0x12249f1f0>
# 12  <Application.Map.Map object at 0x1226599d0>
# 13  <Application.Map.Map object at 0x1226599d0>
# 14  <Application.Map.Map object at 0x1226599d0>
# 15  <Application.Map.Map object at 0x1226599d0>
#
#                                                  path
# 0   [<Application.Cell.Cell object at 0x122424790>...
# 1   [<Application.Cell.Cell object at 0x122424790>...
# 2   [<Application.Cell.Cell object at 0x122424790>...
# 3   [<Application.Cell.Cell object at 0x122424790>...
# 4   [<Application.Cell.Cell object at 0x1224ae370>...
# 5   [<Application.Cell.Cell object at 0x1224ae370>...
# 6   [<Application.Cell.Cell object at 0x1224ae370>...
# 7   [<Application.Cell.Cell object at 0x1224ae370>...
# 8   [<Application.Cell.Cell object at 0x12265e8b0>...
# 9   [<Application.Cell.Cell object at 0x12265e8b0>...
# 10  [<Application.Cell.Cell object at 0x12265e8b0>...
# 11  [<Application.Cell.Cell object at 0x12265e8b0>...
# 12  [<Application.Cell.Cell object at 0x12268e2e0>...
# 13  [<Application.Cell.Cell object at 0x12268e2e0>...
# 14  [<Application.Cell.Cell object at 0x12268e2e0>...
# 15  [<Application.Cell.Cell object at 0x12268e2e0>...

# %%
df.groupby('heuristic')[['total_cost', 'time_elapsed']].min()
# Out:
#            total_cost  time_elapsed
# heuristic
# Chebyshev         788          0.03
# Euclidean         812          0.03
# Manhattan         792          0.03
# None              788          0.05
